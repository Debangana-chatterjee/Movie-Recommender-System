# %% [markdown]
# <a href="https://colab.research.google.com/github/Debangana-chatterjee/Movie-Recommender-System/blob/main/MovieRecommenderSystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## **Importing Datasets**

# %%
movies=pd.read_csv("/content/drive/MyDrive/Datasets/tmdb_5000_movies.csv")
credits=pd.read_csv("/content/drive/MyDrive/Datasets/tmdb_5000_credits.csv")

# %%
movies.shape,credits.shape
# Out:
# ((4803, 20), (4803, 4))

# %%
movies.sample()
# Out:
#         budget                                             genres homepage  \
# 1068  50000000  [{"id": 12, "name": "Adventure"}, {"id": 35, "...      NaN
#
#         id                                           keywords  \
# 1068  7453  [{"id": 211, "name": "bureaucracy"}, {"id": 39...
#
#      original_language                        original_title  \
# 1068                en  The Hitchhiker's Guide to the Galaxy
#
#                                                overview  popularity  \
# 1068  Mere seconds before the Earth is to be demolis...   51.742065
#
#                                    production_companies  \
# 1068  [{"name": "Spyglass Entertainment", "id": 158}...
#
#                                    production_countries release_date  \
# 1068  [{"iso_3166_1": "US", "name": "United States o...   2005-01-15
#
#         revenue  runtime                          spoken_languages    status  \
# 1068  104478416    109.0  [{"iso_639_1": "en", "name": "English"}]  Released
#
# ...

# %%
credits.sample()
# Out:
#       movie_id                      title  \
# 1070      7737  Resident Evil: Extinction
#
#                                                    cast  \
# 1070  [{"cast_id": 1, "character": "Alice", "credit_...
#
#                                                    crew
# 1070  [{"credit_id": "52fe4484c3a36847f809ac1d", "de...

# %% [markdown]
# ## **Data Preprocessing**

# %%
movies=movies.merge(credits,how='inner',left_on='id',right_on='movie_id')

# %%
movies.shape
# Out:
# (4803, 24)

# %%
movies.sample()
# Out:
#        budget                                             genres homepage  \
# 396  90000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...      NaN
#
#        id                                           keywords  \
# 396  9798  [{"id": 417, "name": "corruption"}, {"id": 521...
#
#     original_language      original_title  \
# 396                en  Enemy of the State
#
#                                               overview  popularity  \
# 396  Hotshot Washington lawyer, Robert Dean becomes...   41.207568
#
#                                   production_companies  ...  \
# 396  [{"name": "Jerry Bruckheimer Films", "id": 130...  ...
#
#                              spoken_languages    status  \
# 396  [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                             tagline             title_x  \
# 396  It's not paranoia if they're really after you.  Enemy of the State
#
#     vote_average vote_count movie_id             title_y  \
# ...

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title_x', 'vote_average',
#        'vote_count', 'movie_id', 'title_y', 'cast', 'crew'],
#       dtype='object')

# %%
# genres
# movie_id
# keywords
# title_x
# overview
# cast
# crew

# %%
movies=movies[['movie_id','title_x','overview','genres','keywords','cast','crew']]

# %%
movies.shape
# Out:
# (4803, 7)

# %%
movies.head()
# Out:
#    movie_id                                   title_x  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
movies.rename(columns={'title_x':'title'},inplace=True)

# %%
movies.sample()
# Out:
#       movie_id        title  \
# 2293     29427  The Crazies
#
#                                                overview  \
# 2293  Four friends find themselves trapped in their ...
#
#                                                  genres  \
# 2293  [{"id": 9648, "name": "Mystery"}, {"id": 27, "...
#
#                                                keywords  \
# 2293  [{"id": 321, "name": "terror"}, {"id": 1865, "...
#
#                                                    cast  \
# 2293  [{"cast_id": 9, "character": "David", "credit_...
#
#                                                    crew
# 2293  [{"credit_id": "52fe45dfc3a368484e073bbd", "de...

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.reset_index(drop=True,inplace=True)

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4795      9367                               El Mariachi
# 4796     72766                                 Newlyweds
# 4797    231617                 Signed, Sealed, Delivered
# 4798    126186                          Shanghai Calling
# 4799     25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# ...

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
b=movies.iloc[0].genres
b
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
a=[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]

# %%
['Action','Adventure','Fantasy','Science Fiction']
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
[x['name'] for x in a]
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
type(b)
# Out:
# str

# %%
b
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
import ast

# %%
c=ast.literal_eval(b)
c
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
type(c)
# Out:
# list

# %%
[x['name'] for x in ast.literal_eval(b)]
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
(lambda b:[x['name'] for x in ast.literal_eval(b)])(b)
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
movies['genres']=movies['genres'].apply(lambda b:[x['name'] for x in ast.literal_eval(b)])

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies.iloc[0].keywords
# Out:
# '[{"id": 1463, "name": "culture clash"}, {"id": 2964, "name": "future"}, {"id": 3386, "name": "space war"}, {"id": 3388, "name": "space colony"}, {"id": 3679, "name": "society"}, {"id": 3801, "name": "space travel"}, {"id": 9685, "name": "futuristic"}, {"id": 9840, "name": "romance"}, {"id": 9882, "name": "space"}, {"id": 9951, "name": "alien"}, {"id": 10148, "name": "tribe"}, {"id": 10158, "name": "alien planet"}, {"id": 10987, "name": "cgi"}, {"id": 11399, "name": "marine"}, {"id": 13065, "name": "soldier"}, {"id": 14643, "name": "battle"}, {"id": 14720, "name": "love affair"}, {"id": 165431, "name": "anti war"}, {"id": 193554, "name": "power relations"}, {"id": 206690, "name": "mind and soul"}, {"id": 209714, "name": "3d"}]'

# %%
movies['keywords']=movies['keywords'].apply(lambda b:[x['name'] for x in ast.literal_eval(b)])

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies.iloc[0].cast
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %%
from re import L
def fetch_cast(obj):
    counter=0
    L=[]
    for i in ast.literal_eval(obj):
       if counter!=3:
        L.append(i['name'] )
        counter+=1
       else:
            break
    return L

# %%
fetch_cast(movies.iloc[0].cast)
# Out:
# ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver']

# %%
movies['cast']=movies['cast'].apply(fetch_cast)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies.iloc[0].crew
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
def fetch_director(obj):
    L=[]
    for i in ast.literal_eval(obj):
        if i['job']=='Director':
            L.append(i['name'])
            break
    return L

# %%
fetch_director(movies.iloc[3].crew)
# Out:
# ['Christopher Nolan']

# %%
movies['crew']=movies['crew'].apply(fetch_director)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['overview']=movies['overview'].apply(lambda x:x.split())
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies.head(10)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
# 7     99861                   Avengers: Age of Ultron
# 8       767    Harry Potter and the Half-Blood Prince
# 9    209112        Batman v Superman: Dawn of Justice
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
# ...

# %%
j=movies['genres'][0]
j
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
L=[]
for i in j:
    L.append(i.replace(" ",""))
print(L)
# Out:
# ['Action', 'Adventure', 'Fantasy', 'ScienceFiction']

# %%
(lambda j:[i.replace(" ","")for i in j])(j)
# Out:
# ['Action', 'Adventure', 'Fantasy', 'ScienceFiction']

# %%
movies['genres']=movies['genres'].apply(lambda j:[i.replace(" ","") for i in j])
movies['keywords']=movies['keywords'].apply(lambda j:[i.replace(" ","") for i in j])
movies['cast']=movies['cast'].apply(lambda j:[i.replace(" ","") for i in j])
movies['crew']=movies['crew'].apply(lambda j:[i.replace(" ","")for i in j])

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
movies['tags']=movies['genres']+movies['cast']+movies['crew']+movies['keywords']+movies['overview']

# %%
df=movies[['movie_id','title','tags']]

# %%
df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, S...
# 1  [Adventure, Fantasy, Action, JohnnyDepp, Orlan...
# 2  [Action, Adventure, Crime, DanielCraig, Christ...
# 3  [Action, Crime, Drama, Thriller, ChristianBale...
# 4  [Action, Adventure, ScienceFiction, TaylorKits...

# %%
df['tags']=df['tags'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-60-c4d7f5aefb03>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['tags'].apply(lambda x:" ".join(x))

# %%
df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  Action Adventure Fantasy ScienceFiction SamWor...
# 1  Adventure Fantasy Action JohnnyDepp OrlandoBlo...
# 2  Action Adventure Crime DanielCraig ChristophWa...
# 3  Action Crime Drama Thriller ChristianBale Mich...
# 4  Action Adventure ScienceFiction TaylorKitsch L...

# %%
df.iloc[0].tags
# Out:
# 'Action Adventure Fantasy ScienceFiction SamWorthington ZoeSaldana SigourneyWeaver JamesCameron cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
df['tags'][3]
# Out:
# "Action Crime Drama Thriller ChristianBale MichaelCaine GaryOldman ChristopherNolan dccomics crimefighter terrorist secretidentity burglar hostagedrama timebomb gothamcity vigilante cover-up superhero villainess tragichero terrorism destruction catwoman catburglar imax flood criminalunderworld batman Following the death of District Attorney Harvey Dent, Batman assumes responsibility for Dent's crimes to protect the late attorney's reputation and is subsequently hunted by the Gotham City Police Department. Eight years later, Batman encounters the mysterious Selina Kyle and the villainous Bane, a new terrorist leader who overwhelms Gotham's finest. The Dark Knight resurfaces to protect a city that has branded him an enemy."

# %%
df['tags']=df['tags'].apply(lambda x:x.lower())
# Out:
# <ipython-input-64-285b77110f41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['tags'].apply(lambda x:x.lower())

# %%
df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  action adventure fantasy sciencefiction samwor...
# 1  adventure fantasy action johnnydepp orlandoblo...
# 2  action adventure crime danielcraig christophwa...
# 3  action crime drama thriller christianbale mich...
# 4  action adventure sciencefiction taylorkitsch l...

# %% [markdown]
# ## **Vectorization**

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vect=CountVectorizer(stop_words='english',max_features=5000)
vectors=vect.fit_transform(df['tags'])

# %%
vectors.shape
# Out:
# (4800, 5000)

# %%
vect.get_feature_names_out()[50:200]
# Out:
# array(['abilities', 'ability', 'able', 'aboard', 'abuse', 'abusive',
#        'academy', 'accept', 'accepted', 'accepts', 'access', 'accident',
#        'accidental', 'accidentally', 'accompanied', 'accomplish',
#        'account', 'accountant', 'accused', 'ace', 'achieve', 'act',
#        'acting', 'action', 'actionhero', 'actions', 'activist',
#        'activities', 'activity', 'actor', 'actors', 'actress', 'acts',
#        'actual', 'actually', 'adam', 'adams', 'adamsandler',
#        'adamshankman', 'adaptation', 'adapted', 'addict', 'addicted',
#        'addiction', 'adolescence', 'adopt', 'adopted', 'adoption',
#        'adopts', 'adrienbrody', 'adult', 'adultery', 'adulthood',
#        'adults', 'advantage', 'adventure', 'adventures', 'advertising',
#        'advice', 'affair', 'affairs', 'affection', 'affections',
#        'afghanistan', 'africa', 'african', 'africanamerican',
#        'aftercreditsstinger', 'afterlife', 'aftermath', 'age', 'aged',
# ...

# %%
# Lemmatization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lm=WordNetLemmatizer()

# %%
def lemm(text):
    y=[]
    for word in text.split():
        lemma=lm.lemmatize(word,pos='n')
        lemma=lm.lemmatize(lemma,pos='v')
        lemma=lm.lemmatize(lemma,pos='a')
        lemma=lm.lemmatize(lemma,pos='r')
        y.append(lemma)
    return " ".join(y)

# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")
def lemm_spacy(text):
    doc=nlp(text)
    lemm_text=" ".join([token.lemma_ for token in doc])
    return lemm_text

# %%
df['tags']=df['tags'].apply(lemm_spacy)
# Out:
# <ipython-input-76-a26c9f835315>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['tags'].apply(lemm_spacy)

# %%
vect1=CountVectorizer(stop_words='english',max_features=5000)
vectors=vect1.fit_transform(df['tags']).toarray()

# %%
vectors.shape
# Out:
# (4800, 5000)

# %%
vect1.get_feature_names_out()[50:200]
# Out:
# array(['50', '500', '60', '70', '80', 'aaron', 'aaroneckhart', 'abandon',
#        'abduct', 'abigailbreslin', 'ability', 'able', 'aboard', 'absence',
#        'abuse', 'abusive', 'academic', 'academy', 'accept', 'access',
#        'accident', 'accidental', 'accidentally', 'acclaim', 'accompany',
#        'accomplish', 'account', 'accountant', 'accuse', 'ace', 'achieve',
#        'acquaintance', 'act', 'action', 'actionhero', 'activist',
#        'activity', 'actor', 'actress', 'actual', 'actually', 'adam',
#        'adamsandler', 'adamshankman', 'adapt', 'adaptation', 'add',
#        'addict', 'addiction', 'adjust', 'admit', 'adolescence',
#        'adolescent', 'adopt', 'adoption', 'adrienbrody', 'adult',
#        'adultanimation', 'adultery', 'adulthood', 'advance', 'advantage',
#        'adventure', 'advertising', 'advice', 'affair', 'affect',
#        'affection', 'afghanistan', 'africa', 'african', 'africanamerican',
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)
similarity
# Out:
# array([[1.        , 0.08385255, 0.08519428, ..., 0.04428074, 0.02469324,
#         0.        ],
#        [0.08385255, 1.        , 0.06350006, ..., 0.04950738, 0.        ,
#         0.        ],
#        [0.08519428, 0.06350006, 1.        , ..., 0.05029955, 0.02804964,
#         0.        ],
#        ...,
#        [0.04428074, 0.04950738, 0.05029955, ..., 1.        , 0.0656061 ,
#         0.04484485],
#        [0.02469324, 0.        , 0.02804964, ..., 0.0656061 , 1.        ,
#         0.05001563],
#        [0.        , 0.        , 0.        , ..., 0.04484485, 0.05001563,
#         1.        ]])

# %%
similarity.shape
# Out:
# (4800, 4800)

# %%
similarity[0]
# Out:
# array([1.        , 0.08385255, 0.08519428, ..., 0.04428074, 0.02469324,
#        0.        ])

# %%
list(enumerate(similarity[0]))
# Out:
# [(0, np.float64(1.0000000000000002)),
#  (1, np.float64(0.08385254915624211)),
#  (2, np.float64(0.08519427513705972)),
#  (3, np.float64(0.07161148740394328)),
#  (4, np.float64(0.16878498775964426)),
#  (5, np.float64(0.10758287072798381)),
#  (6, np.float64(0.018505830254940132)),
#  (7, np.float64(0.15975241260567347)),
#  (8, np.float64(0.057735026918962574)),
#  (9, np.float64(0.09325048082403138)),
#  (10, np.float64(0.10397504898200727)),
#  (11, np.float64(0.09644856443408242)),
#  (12, np.float64(0.08808303292720551)),
#  (13, np.float64(0.04303314829119352)),
#  (14, np.float64(0.10690449676496976)),
#  (15, np.float64(0.06175402271944638)),
#  (16, np.float64(0.07694837640638656)),
#  (17, np.float64(0.14171085778131032)),
#  (18, np.float64(0.14056338255793732)),
#  (19, np.float64(0.08377078165833911)),
#  (20, np.float64(0.05175491695067656)),
#  (21, np.float64(0.11359236684941297)),
#  (22, np.float64(0.0632455532033676)),
#  (23, np.float64(0.08519427513705972)),
# ...

# %%
abc=sorted(list(enumerate(similarity[25])),key=lambda x:x[1],reverse=True)
abc[1:6]
# Out:
# [(1559, np.float64(0.2716611781427521)),
#  (1269, np.float64(0.2645914644170347)),
#  (818, np.float64(0.2545033913452094)),
#  (2143, np.float64(0.25084128112136317)),
#  (4190, np.float64(0.24318019154289872))]

# %%
df.iloc[25].title
# Out:
# 'Titanic'

# %%
df.iloc[4190].title
# Out:
# 'Under the Same Moon'

# %%
def recommend(movie):
    index=df[df['title']==movie].index[0]
    distances=sorted(list(enumerate(similarity[index])),key=lambda x:x[1],reverse=True)
    for i in distances[1:6]:
        print(df.iloc[i[0]].title)

# %%
recommend('Skyfall')
# Out:
# Never Say Never Again
# Spectre
# Octopussy
# Quantum of Solace
# Dr. No

# %%
import pickle

# %%
pickle.dump(df,open('movie_list.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
# !pip install streamlit --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 90.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 90.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.9 MB/s eta 0:00:00

# %%
# %%writefile app.py
import pickle
import streamlit as st
import pandas as pd
import requests
movies = pickle.load(open('movie_list.pkl', 'rb'))
similarity = pickle.load(open('similarity.pkl', 'rb'))


st.header('🎬 Movie Recommender System')
movie_list = movies['title'].values
selected_movie = st.selectbox(
    "Type or select a movie from the dropdown",
    movie_list
)

def fetch_poster(movie_id):
    url = "https://api.themoviedb.org/3/movie/{}?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US".format(movie_id)
    data = requests.get(url)
    data = data.json()
    poster_path = data['poster_path']
    full_path = "https://image.tmdb.org/t/p/w500/" + poster_path
    return full_path

def recommend(movie):
    index = movies[movies['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    recommended_movie_names = []
    recommended_movie_posters = []
    for i in distances[1:6]:

        movie_id = movies.iloc[i[0]].movie_id
        recommended_movie_posters.append(fetch_poster(movie_id))
        recommended_movie_names.append(movies.iloc[i[0]].title)

    return recommended_movie_names,recommended_movie_posters

if st.button('Show Recommendation'):
    recommended_movie_names,recommended_movie_posters = recommend(selected_movie)
    cols = st.columns(5)
    for i in range(5):
        with cols[i]:
            st.text(recommended_movie_names[i])
            st.image(recommended_movie_posters[i])
# Out:
# Writing app.py

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ...
#
# ⠙⠹⠸⠼⠴⠦
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.141.232.97:8501
#
# ⠧⠇Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏your url is: https://loud-bags-pull.loca.lt
#   Stopping...
# ^C
